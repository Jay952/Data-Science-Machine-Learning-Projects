# %%
import pandas as pd

# %%
df  = pd.read_excel("Existing_Emplyees.xlsx")

# %%
df.head()
# Out:
#    Emp ID  satisfaction_level  last_evaluation  number_project  \
# 0   14211                0.50             0.73               4
# 1   14210                0.33             0.65               3
# 2   14209                0.85             0.54               3
# 3   14208                0.74             0.95               5
# 4   14207                0.90             0.55               3
#
#    average_montly_hours  time_spend_company  Work_accident  \
# 0                   180                   3              0
# 1                   172                  10              0
# 2                   185                  10              0
# 3                   266                  10              0
# 4                   259                  10              1
#
#    promotion_last_5years        dept salary
# 0                      0          IT    low
# 1                      1   marketing   high
# 2                      1  management   high
# 3                      1  management   high
# ...
