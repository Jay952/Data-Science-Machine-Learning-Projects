# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
Existing_emp  = pd.read_excel("Existing_Emplyees.xlsx")

# %%
Existing_emp.head()
# Out:
#    Emp ID  satisfaction_level  last_evaluation  number_project  \
# 0   14211                0.50             0.73               4
# 1   14210                0.33             0.65               3
# 2   14209                0.85             0.54               3
# 3   14208                0.74             0.95               5
# 4   14207                0.90             0.55               3
#
#    average_montly_hours  time_spend_company  Work_accident  \
# 0                   180                   3              0
# 1                   172                  10              0
# 2                   185                  10              0
# 3                   266                  10              0
# 4                   259                  10              1
#
#    promotion_last_5years        dept salary
# 0                      0          IT    low
# 1                      1   marketing   high
# 2                      1  management   high
# 3                      1  management   high
# ...

# %%
Emp_who_left = pd.read_excel("Employee_who_left.xlsx")

# %%
Emp_who_left.head()
# Out:
#    Emp ID  satisfaction_level  last_evaluation  number_project  \
# 0   14999                0.37             0.52               2
# 1   14998                0.11             0.96               6
# 2   14997                0.37             0.53               2
# 3   14996                0.37             0.48               2
# 4   14995                0.40             0.57               2
#
#    average_montly_hours  time_spend_company  Work_accident  \
# 0                   158                   3              0
# 1                   280                   4              0
# 2                   143                   3              0
# 3                   160                   3              0
# 4                   151                   3              0
#
#    promotion_last_5years     dept salary  Unnamed: 10
# 0                      0  support    low          NaN
# 1                      0  support    low          NaN
# 2                      0  support    low          NaN
# ...

# %% [markdown]
# # Q.1) What type of employees are leaving?

# %%
Emp_who_left["salary"]

# %%
plt.scatter(Emp_who_left["salary"], Emp_who_left["satisfaction_level"])
plt.xlabel("salary")
plt.ylabel("Satisfaction level")
# Out:
# Text(0, 0.5, 'Satisfaction level')

# %%
low_salary_count = 0
medium_salary_count = 0
high_salary_count = 0
for i in Emp_who_left["salary"]:
    if(i == 'low'):
        low_salary_count = low_salary_count + 1
for i in Emp_who_left["salary"]:
    if(i == 'medium'):
        medium_salary_count = medium_salary_count + 1
for i in Emp_who_left["salary"]:
    if(i == 'high'):
        high_salary_count = high_salary_count + 1

# %%
low_salary_count, medium_salary_count, high_salary_count
# Out:
# (2607, 907, 57)

# %%
Overall_count = [2607, 907, 57]
Value = ['low', 'medium', 'high']

# %%
plt.bar(Value, Overall_count)
plt.xlabel('salary')
plt.ylabel("count")
# Out:
# Text(0, 0.5, 'count')

# %%
plt.scatter(Emp_who_left["average_montly_hours"], Emp_who_left["satisfaction_level"])
plt.xlabel('Anerage Monthly Hours')
plt.ylabel('Satisfaction Level')
# Out:
# Text(0, 0.5, 'Satisfaction Level')

# %%
plt.scatter(Existing_emp["average_montly_hours"], Existing_emp["satisfaction_level"])
plt.xlabel('Anerage Monthly Hours')
plt.ylabel('Satisfaction Level')
# Out:
# Text(0, 0.5, 'Satisfaction Level')

# %%
Avg_Time_spent_Emp_who_Left = Emp_who_left["time_spend_company"].mean()
Avg_Time_spent_Emp_who_Left
# Out:
# 3.876505180621675

# %%
Avg_Time_spent_Existing_Emp = Existing_emp["time_spend_company"].mean()
Avg_Time_spent_Existing_Emp
# Out:
# 3.3800315015750786

# %%
new_df_emp_who_left = Emp_who_left[Emp_who_left['satisfaction_level'] < .5]

# %%
new1_df_emp_who_left = new_df_emp_who_left[Emp_who_left['salary'] == 'high']
# Out:
# C:\Users\jayde\anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
new1_df_emp_who_left.head()
# Out:
#      Emp ID  satisfaction_level  last_evaluation  number_project  \
# 57    14942                0.43             0.49               2
# 96    14903                0.45             0.46               2
# 130   14869                0.43             0.55               2
# 169   14830                0.45             0.57               2
# 208   14791                0.39             0.55               2
#
#      average_montly_hours  time_spend_company  Work_accident  \
# 57                    131                   3              0
# 96                    159                   3              0
# 130                   130                   3              0
# 169                   148                   3              0
# 208                   159                   3              0
#
#      promotion_last_5years       dept salary  Unnamed: 10
# 57                       0      RandD   high          NaN
# 96                       0         hr   high          NaN
# ...

# %%
new1_df_emp_who_left
# Out:
#       Emp ID  satisfaction_level  last_evaluation  number_project  \
# 57     14942                0.43             0.49               2
# 96     14903                0.45             0.46               2
# 130    14869                0.43             0.55               2
# 169    14830                0.45             0.57               2
# 208    14791                0.39             0.55               2
# 247    14752                0.45             0.54               2
# 364    14635                0.40             0.46               2
# 403    14596                0.36             0.48               2
# 442    14557                0.10             0.86               6
# 481    14518                0.37             0.46               2
# 520    14479                0.45             0.53               2
# 598    14401                0.44             0.51               2
# 676    14323                0.09             0.85               6
# ...
