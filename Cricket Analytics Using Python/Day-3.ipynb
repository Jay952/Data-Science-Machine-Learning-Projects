# %% [markdown]
# # Sachin Vs Kohli

# %% [markdown]
# ### Statsguru Dataset

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#to display all rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.expand_frame_repr', False)
pd.set_option('max_colwidth', -1)

# %%
df = pd.read_csv('ODI_data.csv')

# %%
df.head(5)
# Out:
#   Innings Player Innings Runs Scored Innings Runs Scored Num Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag Innings Balls Faced Innings Boundary Fours Innings Boundary Sixes Innings Batting Strike Rate Innings Number Opposition         Ground Innings Date      Country  50's  100's Innings Runs Scored Buckets Innings Overs Bowled  Innings Bowled Flag Innings Maidens Bowled Innings Runs Conceded Innings Wickets Taken  4 Wickets  5 Wickets  10 Wickets Innings Wickets Taken Buckets Innings Economy Rate
# ...

# %%
df.columns
# Out:
# Index(['Innings Player', 'Innings Runs Scored', 'Innings Runs Scored Num',
#        'Innings Minutes Batted', 'Innings Batted Flag', 'Innings Not Out Flag',
#        'Innings Balls Faced', 'Innings Boundary Fours',
#        'Innings Boundary Sixes', 'Innings Batting Strike Rate',
#        'Innings Number', 'Opposition', 'Ground', 'Innings Date', 'Country',
#        '50's', '100's', 'Innings Runs Scored Buckets', 'Innings Overs Bowled',
#        'Innings Bowled Flag', 'Innings Maidens Bowled',
#        'Innings Runs Conceded', 'Innings Wickets Taken', '4 Wickets',
#        '5 Wickets', '10 Wickets', 'Innings Wickets Taken Buckets',
#        'Innings Economy Rate'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 28

# %%
len(df)
# Out:
# 171968

# %%
# Runs per innings
# Sr
# 100's
# 50's
# Team contribution

# %%
df['Innings Runs Scored Num'].unique()
# Out:
# array(['65', '42', '18', '17', '13', '11', '5', '0', '120', '71', '20',
#        '16', '3', '2', '1', '-', nan, '40', '6', '4', '87', '54', '46',
#        '30', '12', '69', '39', '14', '10', '9', '8', '7', '82', '52',
#        '41', '15', '98', '43', '19', '111', '48', '36', '25', '67', '60',
#        '84', '59', '55', '47', '85', '49', '45', '34', '29', '22', '74',
#        '28', '77', '50', '32', '23', '35', '122', '100', '95', '103',
#        '113', '53', '96', '27', '64', '58', '33', '31', '73', '56', '86',
#        '62', '106', '24', '57', '104', '26', '66', '51', '118', '105',
#        '101', '21', '79', '44', '102', '88', '80', '72', '97', '68', '89',
#        '38', '83', '63', '148', '166', '90', '76', '37', '70', '124',
#        '94', '140', '153', '107', '117', '121', '92', '78', '75', '114',
#        '115', '130', '128', '151', '110', '138', '135', '109', '61',
#        '179', '170', '112', '116', '91', '143', '93', '123', '145', '81',
# ...

# %%
df = df[df['Innings Runs Scored Num'] != '-']

# %%
df['Innings Runs Scored Num'].unique()
# Out:
# array(['65', '42', '18', '17', '13', '11', '5', '0', '120', '71', '20',
#        '16', '3', '2', '1', nan, '40', '6', '4', '87', '54', '46', '30',
#        '12', '69', '39', '14', '10', '9', '8', '7', '82', '52', '41',
#        '15', '98', '43', '19', '111', '48', '36', '25', '67', '60', '84',
#        '59', '55', '47', '85', '49', '45', '34', '29', '22', '74', '28',
#        '77', '50', '32', '23', '35', '122', '100', '95', '103', '113',
#        '53', '96', '27', '64', '58', '33', '31', '73', '56', '86', '62',
#        '106', '24', '57', '104', '26', '66', '51', '118', '105', '101',
#        '21', '79', '44', '102', '88', '80', '72', '97', '68', '89', '38',
#        '83', '63', '148', '166', '90', '76', '37', '70', '124', '94',
#        '140', '153', '107', '117', '121', '92', '78', '75', '114', '115',
#        '130', '128', '151', '110', '138', '135', '109', '61', '179',
#        '170', '112', '116', '91', '143', '93', '123', '145', '81', '150',
# ...

# %%
df = df.dropna(subset = ['Innings Runs Scored Num'])

# %%
df['Innings Runs Scored Num'].unique()
# Out:
# array(['65', '42', '18', '17', '13', '11', '5', '0', '120', '71', '20',
#        '16', '3', '2', '1', '40', '6', '4', '87', '54', '46', '30', '12',
#        '69', '39', '14', '10', '9', '8', '7', '82', '52', '41', '15',
#        '98', '43', '19', '111', '48', '36', '25', '67', '60', '84', '59',
#        '55', '47', '85', '49', '45', '34', '29', '22', '74', '28', '77',
#        '50', '32', '23', '35', '122', '100', '95', '103', '113', '53',
#        '96', '27', '64', '58', '33', '31', '73', '56', '86', '62', '106',
#        '24', '57', '104', '26', '66', '51', '118', '105', '101', '21',
#        '79', '44', '102', '88', '80', '72', '97', '68', '89', '38', '83',
#        '63', '148', '166', '90', '76', '37', '70', '124', '94', '140',
#        '153', '107', '117', '121', '92', '78', '75', '114', '115', '130',
#        '128', '151', '110', '138', '135', '109', '61', '179', '170',
#        '112', '116', '91', '143', '93', '123', '145', '81', '150', '162',
# ...

# %%
# convert to dateTime

# %%
df['Innings Date'] = pd.to_datetime(df['Innings Date'])

# %%
df['year'] = df['Innings Date'].dt.year

# %%
df.head(5)
# Out:
#   Innings Player Innings Runs Scored Innings Runs Scored Num Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag Innings Balls Faced Innings Boundary Fours Innings Boundary Sixes Innings Batting Strike Rate Innings Number Opposition         Ground Innings Date      Country  50's  100's Innings Runs Scored Buckets Innings Overs Bowled  Innings Bowled Flag Innings Maidens Bowled Innings Runs Conceded Innings Wickets Taken  4 Wickets  5 Wickets  10 Wickets Innings Wickets Taken Buckets Innings Economy Rate  year
# ...

# %%
df['Innings Runs Scored Num'] = df['Innings Runs Scored Num'].astype('int')

# %%
# Sachin 1994 - 2004
# Virat 2009 - 2019

# %%
sachin_df = df[(df.year >= 1994) & (df.year <= 2004)]

# %%
virat_df = df[(df.year >= 2009) & (df.year <= 2019)]

# %%
sachin_df.head(5)
# Out:
#       Innings Player Innings Runs Scored  Innings Runs Scored Num Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag Innings Balls Faced Innings Boundary Fours Innings Boundary Sixes Innings Batting Strike Rate Innings Number    Opposition Ground Innings Date Country  50's  100's Innings Runs Scored Buckets Innings Overs Bowled  Innings Bowled Flag Innings Maidens Bowled Innings Runs Conceded Innings Wickets Taken  4 Wickets  5 Wickets  10 Wickets Innings Wickets Taken Buckets Innings Economy Rate  year
# ...

# %%
virat_df.head(5)
# Out:
#   Innings Player Innings Runs Scored  Innings Runs Scored Num Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag Innings Balls Faced Innings Boundary Fours Innings Boundary Sixes Innings Batting Strike Rate Innings Number Opposition         Ground Innings Date      Country  50's  100's Innings Runs Scored Buckets Innings Overs Bowled  Innings Bowled Flag Innings Maidens Bowled Innings Runs Conceded Innings Wickets Taken  4 Wickets  5 Wickets  10 Wickets Innings Wickets Taken Buckets Innings Economy Rate  year
# ...

# %%
# Runs per innings = Total runs/Total innings
# Sr = (Total runs/Total Balls)*100
# 100's = Sum(100's)
# 50's = Sum(50's)
# Team contribution = Player Runs/ Team Run (ex: Virat 50/Team India 150 : 33.33%)

# %%
df.dtypes
# Out:
# Innings Player                   object
# Innings Runs Scored              object
# Innings Runs Scored Num          int32
# Innings Minutes Batted           object
# Innings Batted Flag              float64
# Innings Not Out Flag             float64
# Innings Balls Faced              object
# Innings Boundary Fours           object
# Innings Boundary Sixes           object
# Innings Batting Strike Rate      object
# Innings Number                   object
# Opposition                       object
# Ground                           object
# Innings Date                     datetime64[ns]
# Country                          object
# 50's                             float64
# 100's                            float64
# Innings Runs Scored Buckets      object
# Innings Overs Bowled             object
# Innings Bowled Flag              float64
# Innings Maidens Bowled           object
# Innings Runs Conceded            object
# Innings Wickets Taken            object
# ...

# %%
# df.dtypes
# sachin_df.to_csv('sachin_data.csv')

# %%
# What is the Total runs scored by Sachin in these time frames

# %%
sachin_df.head()
# Out:
#       Innings Player Innings Runs Scored  Innings Runs Scored Num Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag Innings Balls Faced Innings Boundary Fours Innings Boundary Sixes Innings Batting Strike Rate Innings Number    Opposition Ground Innings Date Country  50's  100's Innings Runs Scored Buckets Innings Overs Bowled  Innings Bowled Flag Innings Maidens Bowled Innings Runs Conceded Innings Wickets Taken  4 Wickets  5 Wickets  10 Wickets Innings Wickets Taken Buckets Innings Economy Rate  year
# ...

# %%
sdf = sachin_df[sachin_df['Innings Player'] == 'SR Tendulkar']

# %%
sdf.head()
# Out:
#       Innings Player Innings Runs Scored  Innings Runs Scored Num Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag Innings Balls Faced Innings Boundary Fours Innings Boundary Sixes Innings Batting Strike Rate Innings Number    Opposition         Ground Innings Date Country  50's  100's Innings Runs Scored Buckets Innings Overs Bowled  Innings Bowled Flag Innings Maidens Bowled Innings Runs Conceded Innings Wickets Taken  4 Wickets  5 Wickets  10 Wickets Innings Wickets Taken Buckets Innings Economy Rate  year
# ...

# %%
sum(sdf['Innings Runs Scored Num'])
# Out:
# 11818

# %%
virat_df.head(20)
# Out:
#     Innings Player Innings Runs Scored  Innings Runs Scored Num Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag Innings Balls Faced Innings Boundary Fours Innings Boundary Sixes Innings Batting Strike Rate Innings Number     Opposition         Ground Innings Date      Country  50's  100's Innings Runs Scored Buckets Innings Overs Bowled  Innings Bowled Flag Innings Maidens Bowled Innings Runs Conceded Innings Wickets Taken  4 Wickets  5 Wickets  10 Wickets Innings Wickets Taken Buckets Innings Economy Rate  year
# ...

# %%
virat_df['Innings Player'].nunique
# Out:
# <bound method IndexOpsMixin.nunique of 0        E Lewis
# 1        N Pooran
# 2        SO Hetmyer
# 3        RL Chase
# 4        SS Cottrell
# 5        JO Holder
# 6        CH Gayle
# 7        SD Hope
# 8        CR Brathwaite
# 9        KAJ Roach
# 10       O Thomas
# 11       V Kohli
# 12       SS Iyer
# 13       RR Pant
# 14       RG Sharma
# 15       RA Jadeja
# 16       KM Jadhav
# 17       Mohammed Shami
# 18       S Dhawan
# 19       B Kumar
# 44       E Lewis
# 45       SD Hope
# 46       CH Gayle
# 88       AD Mathews
# 89       BKG Mendis
# 90       FDM Karunaratne
# 91       MDKJ Perera
# 92       MD Shanaka
# 93       GSNFG Jayasuriya
# 94       PWH de Silva
# 95       WIA Fernando
# 96       CAK Rajitha
# 97       A Dananjaya
# 99       Soumya Sarkar
# 100      Taijul Islam
# 101      Anamul Haque
# 102      Mushfiqur Rahim
# 103      Mahmudullah
# 104      Mehidy Hasan Miraz
# 105      Sabbir Rahman
# 106      Mohammad Mithun
# 107      Tamim Iqbal
# ...

# %%
kdf = virat_df[virat_df['Innings Player'] == 'V Kohli']

# %%
kdf.head(20)
# Out:
#      Innings Player Innings Runs Scored  Innings Runs Scored Num Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag Innings Balls Faced Innings Boundary Fours Innings Boundary Sixes Innings Batting Strike Rate Innings Number      Opposition              Ground Innings Date Country  50's  100's Innings Runs Scored Buckets Innings Overs Bowled  Innings Bowled Flag Innings Maidens Bowled Innings Runs Conceded Innings Wickets Taken  4 Wickets  5 Wickets  10 Wickets Innings Wickets Taken Buckets Innings Economy Rate  year
# ...

# %%
sum(kdf['Innings Runs Scored Num'])
# Out:
# 11247

# %%
# RPI - Sachin, Virat

# %%
len(sdf), len(kdf)
# Out:
# (271, 224)

# %%
sum(sdf['Innings Runs Scored Num'])/len(sdf)
# Out:
# 43.608856088560884

# %%
sum(kdf['Innings Runs Scored Num'])/len(kdf)
# Out:
# 50.20982142857143

# %%
# SR

# %%
sdf['Innings Balls Faced'] = sdf['Innings Balls Faced'].astype('int')
kdf['Innings Balls Faced'] = kdf['Innings Balls Faced'].astype('int')

# %%
sum(sdf['Innings Balls Faced'])
# Out:
# 13397

# %%
( sum(sdf['Innings Runs Scored Num']) / sum(sdf['Innings Balls Faced']) )*100
# Out:
# 88.21377920429947

# %%
( sum(kdf['Innings Runs Scored Num']) / sum(kdf['Innings Balls Faced']) )*100
# Out:
# 93.56126778138258

# %%
#100's

# %%
sum(sdf['100\'s'])
# Out:
# 37.0

# %%
sum(kdf['100\'s'])
# Out:
# 42.0

# %%
#50's

# %%
sum(sdf['50\'s'])
# Out:
# 57.0

# %%
sum(kdf["50\'s"])
# Out:
# 53.0

# %%
# Team Contribution - Runs scored by each player/ Runs by scored the Team

# %%
sum(sdf['Innings Runs Scored Num']), sum(kdf['Innings Runs Scored Num'])
# Out:
# (11818, 11247)

# %%
# 1994-2004 = All players

# %%
sum( sachin_df[sachin_df.Country == 'India']['Innings Runs Scored Num'] )
# Out:
# 69715

# %%
# 2009-2019 = All players
sum( virat_df[virat_df.Country == 'India']['Innings Runs Scored Num'] )
# Out:
# 63867

# %%
sum(sdf['Innings Runs Scored Num']) / sum( sachin_df[sachin_df.Country == 'India']['Innings Runs Scored Num'] )
# Out:
# 0.16951875493078963

# %%
sum(kdf['Innings Runs Scored Num']) / sum( virat_df[virat_df.Country == 'India']['Innings Runs Scored Num'] )
# Out:
# 0.17610033350556625

# %% [markdown]
# # Visualisation

# %%
sachin_df.head()
# Out:
#       Innings Player Innings Runs Scored  Innings Runs Scored Num Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag Innings Balls Faced Innings Boundary Fours Innings Boundary Sixes Innings Batting Strike Rate Innings Number    Opposition Ground Innings Date Country  50's  100's Innings Runs Scored Buckets Innings Overs Bowled  Innings Bowled Flag Innings Maidens Bowled Innings Runs Conceded Innings Wickets Taken  4 Wickets  5 Wickets  10 Wickets Innings Wickets Taken Buckets Innings Economy Rate  year
# ...

# %%
sachin_df.groupby(['Innings Player'])['Innings Runs Scored Num'].sum().sort_values(ascending = False)
# Out:
# Innings Player
# SR Tendulkar           11818
# SC Ganguly             9911
# ST Jayasuriya          9297
# Inzamam-ul-Haq         8561
# R Dravid               7751
# RT Ponting             7422
# Saeed Anwar            7320
# JH Kallis              7267
# MS Atapattu            7253
# MG Bevan               6912
# ME Waugh               6897
# G Kirsten              6787
# AC Gilchrist           6661
# SP Fleming             6539
# BC Lara                6504
# GW Flower              6183
# A Flower               6142
# Mohammad Yousuf        6096
# NJ Astle               6030
# PA de Silva            5772
# JN Rhodes              5239
# A Jadeja               5079
# M Azharuddin           4954
# ADR Campbell           4949
# HH Gibbs               4920
# WJ Cronje              4840
# Ijaz Ahmed             4814
# S Chanderpaul          4631
# SR Waugh               4582
# CL Cairns              4479
# DPMD Jayawardene       4436
# Shahid Afridi          4125
# ...

# %%
sachin_df.groupby(['Innings Player'])['Innings Runs Scored Num'].sum().sort_values(ascending = False).head(10).plot(kind = 'bar')

# %%
virat_df.groupby(['Innings Player'])['Innings Runs Scored Num'].sum().sort_values(ascending = False)
# Out:
# Innings Player
# V Kohli                  11247
# RG Sharma                8083
# HM Amla                  7745
# TM Dilshan               7296
# KC Sangakkara            7275
# AB de Villiers           7247
# LRPL Taylor              7059
# MS Dhoni                 6838
# EJG Morgan               6748
# MJ Guptill               6626
# KS Williamson            6132
# JE Root                  5856
# AD Mathews               5781
# Mohammad Hafeez          5740
# Tamim Iqbal              5630
# Mushfiqur Rahim          5565
# F du Plessis             5507
# S Dhawan                 5482
# DA Warner                4990
# Shakib Al Hasan          4947
# Q de Kock                4907
# WU Tharanga              4818
# DPMD Jayawardene         4801
# AJ Finch                 4559
# SR Watson                4494
# H Masakadza              4415
# BRM Taylor               4364
# SK Raina                 4323
# JP Duminy                4299
# PR Stirling              4026
# ...

# %%
virat_df.groupby(['Innings Player'])['Innings Runs Scored Num'].sum().sort_values(ascending = False).head(10).plot(kind = 'bar')

# %%
sdf.groupby(['year'])['Innings Runs Scored Num'].sum()
# Out:
# year
# 1994    1089
# 1995    444
# 1996    1611
# 1997    1011
# 1998    1894
# 1999    843
# 2000    1328
# 2001    904
# 2002    741
# 2003    1141
# 2004    812
# Name: Innings Runs Scored Num, dtype: int32

# %%
sdf.groupby(['year'])['Innings Runs Scored Num'].sum().plot(kind = 'bar')

# %%
kdf.groupby(['year'])['Innings Runs Scored Num'].sum()
# Out:
# year
# 2009    325
# 2010    995
# 2011    1381
# 2012    1026
# 2013    1268
# 2014    1054
# 2015    623
# 2016    739
# 2017    1460
# 2018    1202
# 2019    1174
# Name: Innings Runs Scored Num, dtype: int32

# %%
kdf.groupby(['year'])['Innings Runs Scored Num'].sum().plot(kind = 'bar')

# %% [markdown]
# # Normalisation

# %%
# RPI - Sachin, Virat
sum(sdf['Innings Runs Scored Num'])/len(sdf), sum(kdf['Innings Runs Scored Num'])/len(kdf)
# Out:
# (43.608856088560884, 50.20982142857143)

# %%
# Kohli_df = players runs with Kohli
# players runs excluding Kohli => not_kohli = kohli_df[kohli_df.player_name != 'V Kohli']

# %%
sum(virat_df['Innings Runs Scored Num']) / len(virat_df)
# Out:
# 24.99673202614379

# %%
non_kohli_df = virat_df[virat_df['Innings Player'] != 'V kohli']

# %%
non_sachin_df = sachin_df[sachin_df['Innings Player'] != 'SR Tendulkar']

# %%
sum(non_kohli_df['Innings Runs Scored Num']) / len(non_kohli_df)
# Out:
# 24.99673202614379

# %%
sum(non_sachin_df['Innings Runs Scored Num']) / len(non_sachin_df)
# Out:
# 22.43512946754194

# %%
(sum(kdf['Innings Runs Scored Num'])/len(kdf)) / (sum(non_kohli_df['Innings Runs Scored Num']) / len(non_kohli_df))
# Out:
# 2.008655426479652

# %%
( sum(sdf['Innings Runs Scored Num'])/len(sdf)) / (sum(non_sachin_df['Innings Runs Scored Num']) / len(non_sachin_df))
# Out:
# 1.9437755485945407

# %%
# kohli => others
# SR = V = 93, Other = 80, V/other, S/other
#100's - Number of matches to score a 100
#50's - Number of matches to score a 50
# Team Contribution - V_cont/O_cont

# %%
200/37
# Out:
# 5.405405405405405

# %% [markdown]
# # Conclusion

# %% [markdown]
# ## Runs per innings:

# %%
Sachin : 1.94
Kohli : 2.03

# %% [markdown]
# ## Strike Rate:

# %%
Sachin : 1.22
Kohli : 1.12

# %% [markdown]
# ## Matches for a 100:

# %%
Sachin : .15
Kohli : .18

# %% [markdown]
# ## Matches for a 50:

# %%
Sachin : .57
Kohli : .55

# %% [markdown]
# ## Team Contribution:

# %%
Sachin : 16.9 
Kohli : 17.6
